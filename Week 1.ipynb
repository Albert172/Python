# %%
from PIL import Image
from skimage.io import imread, imsave, imshow, show
import matplotlib.pylab as plt

# %%
im = Image.open("./Test.jpg")
im.show()

# %%
print (im.width,im.height, im.mode, im.format)
# Out:
# 6528 4896 RGB JPEG

# %%
import imageio
im2 = imageio.imread("./Test.jpg")
plt.imshow(im2)

# %%
print (im2.shape)
# Out:
# (4896, 6528, 3)

# %%
import matplotlib.image as mpimg
im3 = mpimg.imread("./Test.jpg")
plt.imshow(im3)
print (im3.shape)
# Out:
# (4896, 6528, 3)

# %%
imu = im.resize((im.width*2,im.height*2))
plt.imshow(imu)

# %%
fig,ax = plt.subplots(1,2)
ax[0].imshow(im);
ax[1].imshow(imu);

# %%
import numpy as np
import cv2

# %%
im4 = cv2.imread ("./Test.jpg")
cv2.imshow("image",im4)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
im4 = cv2.imread ("./Test.jpg",0)
cv2.imshow("image",im4)
cv2.waitKey(0)
cv2.destroyAllWindows()
